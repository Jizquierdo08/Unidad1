# %%
def example(a,b):
    return a-b

def mult_numbers(n1,n2,nop='None'):
    if nop== 'None':
        return n1*n2
    return n1*n2*nop


v1 = 12
v2 = 12.23
v3 = "Hola, soy Julieta"
v4 = True
v5 = example

print(type(v1))
print(type(v2))
print(type(v3))
print(type(v4))
print(type(v5))
print()

square_area = mult_numbers
prism_volume = mult_numbers

print("square_area = ",square_area(5,5))
print("prism_volume = ",prism_volume(1,2,3))
print()

t = tuple()
t = ('Hola',123,321)

for i in t:
    print(i)

print()

l = [1,4,8,5,-1]

for j in l:
    print(j)

print()
print("Min = ",min(l))
print()
print("Max = ",max(l))
print()

l.append(23431)
for j in l:
    print(j)
    
print()
print(l[0])
print()

string = "julieta,luis,lua"
sp = string.split(',')
print(sp)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'function'>
#
# square_area =  25
# prism_volume =  6
#
# Hola
# 123
# 321
#
# 1
# 4
# 8
# 5
# -1
#
# Min =  -1
#
# Max =  8
#
# 1
# 4
# 8
# 5
# -1
# 23431
#
# 1
#
# ['julieta', 'luis', 'lua']
